# %% [markdown]
# Part 1:
# Electrical Vehicles (EVs)

# %% [markdown]
# Part 2:

# %%
# !pip install praw
import pandas as pd
import praw
import csv
import asyncio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.3/189.3 kB 4.0 MB/s eta 0:00:00
# ...

# %%
#Kaggle Data

import json
import os

# Adding Kaggle credentials
kaggle_credentials = {
    "username": "kashafrajpoot",
    "key": "3b379166602b101144ee84dce16a1af7"
}


os.makedirs("/root/.kaggle", exist_ok=True)


with open("/root/.kaggle/kaggle.json", "w") as f:
    json.dump(kaggle_credentials, f)

os.chmod("/root/.kaggle/kaggle.json", 600)

# Testing the API
# !kaggle datasets list
# Out:
# ref                                                   title                                           size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------  ---------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# asinow/car-price-dataset                              Car Price Dataset                              135KB  2025-01-26 19:53:28          10413        142  1.0
# adilshamim8/education-and-career-success              Education & Career Success.                    118KB  2025-02-03 05:24:20           2126         35  1.0
# sachinkumar62/datascience-job-data                    data science job data set                      247KB  2025-02-12 14:15:12            590         26  1.0
# anandshaw2001/netflix-movies-and-tv-shows             Netflix Movies and TV Shows                      1MB  2025-01-03 10:33:01          18959        474  1.0
# ...

# %%
# !kaggle datasets download -d mariusborel/electric-vhicule-population-data
# Out:
# Dataset URL: https://www.kaggle.com/datasets/mariusborel/electric-vhicule-population-data
# License(s): ODC Attribution License (ODC-By)
# ...
#   0% 0.00/6.72M [00:00<?, ?B/s]
# 100% 6.72M/6.72M [00:00<00:00, 71.1MB/s]

# %%
# !unzip electric-vhicule-population-data.zip -d /content/
# Out:
# Archive:  electric-vhicule-population-data.zip
#   inflating: /content/Electric_Vehicle_Population_Data.csv

# %%
import os
print(os.listdir("/content/"))
# Out:
# ['.config', 'Electric_Vehicle_Population_Data.csv', 'electric-vhicule-population-data.zip', 'sample_data']

# %%
import pandas as pd


df2 = pd.read_csv("/content/Electric_Vehicle_Population_Data.csv")


df2.head()
# Out:
#    VIN (1-10)    County       City State  Postal Code  Model Year       Make  \
# 0  JTMAB3FV3P    Kitsap    Seabeck    WA      98380.0        2023     TOYOTA
# 1  1N4AZ1CP6J    Kitsap  Bremerton    WA      98312.0        2018     NISSAN
# 2  5YJ3E1EA4L      King    Seattle    WA      98101.0        2020      TESLA
# 3  1N4AZ0CP8E      King    Seattle    WA      98125.0        2014     NISSAN
# 4  1G1FX6S00H  Thurston       Yelm    WA      98597.0        2017  CHEVROLET
#
#         Model                   Electric Vehicle Type  \
# 0  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 1        LEAF          Battery Electric Vehicle (BEV)
# 2     MODEL 3          Battery Electric Vehicle (BEV)
# 3        LEAF          Battery Electric Vehicle (BEV)
# 4     BOLT EV          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible            42.0
# ...

# %%
df2.to_csv("/content/kaggle_ev_data.csv", index=False)
print("Saved dataset as kaggle_ev_data.csv")
# Out:
# Saved dataset as kaggle_ev_data.csv

# %%
df2.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                  1
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         8
# Base MSRP                                              8
# Legislative District                                 442
# DOL Vehicle ID                                         0
# Vehicle Location                                       8
# Electric Utility                                       3
# ...

# %%
##data cleaning kaggle data

df2.duplicated().sum() #checking for duplicates #no duplicates

df2=df2.drop(columns=['Legislative District'])

minor_missing=['County', 'City', 'Postal Code', 'Electric Utility', '2020 Census Tract','Model'] #replacing the missing values in categorical columns with 'unknown'
df2[minor_missing]=df2[minor_missing].fillna('Unknown')

df2[' Electric Range']=df2['Electric Range'].fillna(df2['Electric Range'].median()) #filling numerical missing values with median
df2['Base MSRP']=df2['Base MSRP'].fillna(df2['Base MSRP'].median())


df2=df2.dropna(subset=['Vehicle Location']) ##removing rows with missing vehicle location

# %%
print(df2.isnull().sum())
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       8
# Base MSRP                                            0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
#  Electric Range                                      0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 205431 entries, 0 to 205438
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         205431 non-null  object
#  1   County                                             205431 non-null  object
#  2   City                                               205431 non-null  object
#  3   State                                              205431 non-null  object
#  4   Postal Code                                        205431 non-null  object
#  5   Model Year                                         205431 non-null  int64
#  6   Make                                               205431 non-null  object
#  7   Model                                              205431 non-null  object
# ...

# %%
df2.describe()
# Out:
#           Model Year  Electric Range      Base MSRP  DOL Vehicle ID  \
# count  205431.000000   205423.000000  205431.000000    2.054310e+05
# mean     2020.960425       52.164378     922.253603    2.277151e+08
# std         2.989063       88.076693    7760.582736    7.205596e+07
# min      1997.000000        0.000000       0.000000    4.469000e+03
# 25%      2019.000000        0.000000       0.000000    1.935324e+08
# 50%      2022.000000        0.000000       0.000000    2.382368e+08
# 75%      2023.000000       48.000000       0.000000    2.618718e+08
# max      2025.000000      337.000000  845000.000000    4.792548e+08
#
#         Electric Range
# count    205431.000000
# mean         52.162346
# std          88.075580
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          48.000000
# max         337.000000
